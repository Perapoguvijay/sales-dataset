# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
file=r"C:\Users\vijay\OneDrive\Desktop\EDA Datasets csv\Census+2011.csv"
census=pd.read_csv(file)
census
# Out:
#      District_code                   State_name              District_name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# ...

# %%
correlation=census.corr(numeric_only=True)
correlation
# Out:
#                       District_code  Population      Male    Female  Literate  \
# District_code              1.000000    0.167643  0.149415  0.186923  0.224798
# Population                 0.167643    1.000000  0.999167  0.999037  0.972610
# Male                       0.149415    0.999167  1.000000  0.996414  0.970961
# Female                     0.186923    0.999037  0.996414  1.000000  0.972575
# Literate                   0.224798    0.972610  0.970961  0.972575  1.000000
# Workers                    0.276291    0.972279  0.968819  0.974191  0.955314
# Male_Workers               0.212273    0.989354  0.989408  0.987456  0.981390
# Female_Workers             0.387190    0.803693  0.792590  0.814135  0.768228
# Cultivator_Workers         0.040757    0.556407  0.554079  0.557876  0.455652
# Agricultural_Workers       0.309034    0.661252  0.650263  0.671835  0.548333
# Household_Workers          0.079228    0.699595  0.695712  0.702468  0.661045
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
census.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %% [markdown]
# ## 1.How will you hide the indexs of the dataframe.

# %%
census.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
census.style.hide_index_
# Out:
# [False]

# %%
census
# Out:
#      District_code                   State_name              District_name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# ...

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ## 2.How can we set the caption/heading on the dataframe

# %%
census.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
census.style.set_caption('Indian climate census 2011 dataset')
# Out:
# <style type="text/css">
# </style>
# <table id="T_130eb">
#   <caption>Indian climate census 2011 dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_130eb_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_130eb_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_130eb_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_130eb_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_130eb_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_130eb_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_130eb_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_130eb_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_130eb_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
# ...

# %% [markdown]
# ## 3.Show the records related with the districts- New Delhi,Lucknow,Jaipur

# %%
census.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
census[census['District_name']=='New Delhi']
# Out:
#     District_code    State_name District_name  Population   Male  Female  \
# 93             94  NCT OF DELHI     New Delhi      142004  77942   64062
#
#     Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93    114179    59541         46940           12601  ...        4852   2933
#
#     Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93        312    679                15942             17742
#
#     Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 93               23934           76076            43913         21773
#
# [1 rows x 25 columns]

# %%
census[census['District_name'].isin(['New Delhi','Lucknow','Jaipur'])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# ## 4.Calculate state-wise

# %% [markdown]
# ## A.Total number of population.

# %% [markdown]
# ## B.Total no.of population with different religions

# %%
census.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
census.groupby('State_name')['Population'].sum().sort_values(ascending=False)
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %%
census.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
census.groupby('State_name')[['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains']].sum().sort_values(by='Hindus')
# Out:
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# LAKSHADWEEP                       1788     62268         317         8
# MIZORAM                          30136     14832      956331       286
# NAGALAND                        173054     48963     1739651      1890
# DAMAN AND DIU                   220150     19277        2820       172
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286
# DADRA AND NAGAR HAVELI          322857     12922        5113       217
# MEGHALAYA                       342078    130399     2213027      3045
# SIKKIM                          352662      9867       60522      1868
# ARUNACHAL PRADESH               401876     27045      418732      3287
# CHANDIGARH                      852574     51447        8720    138329
# GOA                             963877    121564      366130      1473
# PONDICHERRY                    1089409     75556       78550       297
# ...

# %% [markdown]
# ## 5.How many Male Workers were there in Maharasthtra state

# %%
census.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
census[census['State_name']=='MAHARASHTRA']
# Out:
#      District_code   State_name    District_name  Population     Male  \
# 496            497  MAHARASHTRA        Nandurbar     1648295   833170
# 497            498  MAHARASHTRA            Dhule     2050862  1054031
# 498            499  MAHARASHTRA          Jalgaon     4229917  2197365
# 499            500  MAHARASHTRA          Buldana     2586258  1337560
# 500            501  MAHARASHTRA            Akola     1813906   932334
# 501            502  MAHARASHTRA           Washim     1197160   620302
# 502            503  MAHARASHTRA         Amravati     2888445  1480768
# 503            504  MAHARASHTRA           Wardha     1300774   668385
# 504            505  MAHARASHTRA           Nagpur     4653570  2384975
# 505            506  MAHARASHTRA         Bhandara     1200334   605520
# 506            507  MAHARASHTRA          Gondiya     1322507   661554
# 507            508  MAHARASHTRA       Gadchiroli     1072942   541328
# ...

# %%
census[census['State_name']=='MAHARASHTRA']['Male'].sum()
# Out:
# 58243056

# %%
census.shape
# Out:
# (640, 25)

# %% [markdown]
# - Female workers

# %%
census[census['State_name']=='ANDHRA PRADESH']['Female'].sum()
# Out:
# 42138631

# %% [markdown]
# ## 6.How to set a column as index of the dataframe

# %%
census.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
census.set_index('District_name')
# Out:
#                            District_code                   State_name  \
# District_name
# Kupwara                                1            JAMMU AND KASHMIR
# Badgam                                 2            JAMMU AND KASHMIR
# Leh(Ladakh)                            3            JAMMU AND KASHMIR
# Kargil                                 4            JAMMU AND KASHMIR
# Punch                                  5            JAMMU AND KASHMIR
# ...                                  ...                          ...
# Mahe                                 636                  PONDICHERRY
# Karaikal                             637                  PONDICHERRY
# Nicobars                             638  ANDAMAN AND NICOBAR ISLANDS
# North  AND Middle Andaman            639  ANDAMAN AND NICOBAR ISLANDS
# South Andaman                        640  ANDAMAN AND NICOBAR ISLANDS
#
#                            Population    Male  Female  Literate  Workers  \
# District_name
# ...

# %%
census.set_index('State_name')
# Out:
#                              District_code              District_name  \
# State_name
# JAMMU AND KASHMIR                        1                    Kupwara
# JAMMU AND KASHMIR                        2                     Badgam
# JAMMU AND KASHMIR                        3                Leh(Ladakh)
# JAMMU AND KASHMIR                        4                     Kargil
# JAMMU AND KASHMIR                        5                      Punch
# ...                                    ...                        ...
# PONDICHERRY                            636                       Mahe
# PONDICHERRY                            637                   Karaikal
# ANDAMAN AND NICOBAR ISLANDS            638                   Nicobars
# ANDAMAN AND NICOBAR ISLANDS            639  North  AND Middle Andaman
# ANDAMAN AND NICOBAR ISLANDS            640              South Andaman
#
#                              Population    Male  Female  Literate  Workers  \
# State_name
# ...

# %% [markdown]
# ## 7.a) Add a suffix to the columnb names
#
# ## 7.b) Add a prefix to the columns names

# %%
census.add_suffix('_vijay')
# Out:
#      District_code_vijay             State_name_vijay  \
# 0                      1            JAMMU AND KASHMIR
# 1                      2            JAMMU AND KASHMIR
# 2                      3            JAMMU AND KASHMIR
# 3                      4            JAMMU AND KASHMIR
# 4                      5            JAMMU AND KASHMIR
# ..                   ...                          ...
# 635                  636                  PONDICHERRY
# 636                  637                  PONDICHERRY
# 637                  638  ANDAMAN AND NICOBAR ISLANDS
# 638                  639  ANDAMAN AND NICOBAR ISLANDS
# 639                  640  ANDAMAN AND NICOBAR ISLANDS
#
#            District_name_vijay  Population_vijay  Male_vijay  Female_vijay  \
# 0                      Kupwara            870354      474190        396164
# 1                       Badgam            753745      398041        355704
# 2                  Leh(Ladakh)            133487       78971         54516
# ...

# %%
census.add_prefix('_Vijay')
# Out:
#      _VijayDistrict_code             _VijayState_name  \
# 0                      1            JAMMU AND KASHMIR
# 1                      2            JAMMU AND KASHMIR
# 2                      3            JAMMU AND KASHMIR
# 3                      4            JAMMU AND KASHMIR
# 4                      5            JAMMU AND KASHMIR
# ..                   ...                          ...
# 635                  636                  PONDICHERRY
# 636                  637                  PONDICHERRY
# 637                  638  ANDAMAN AND NICOBAR ISLANDS
# 638                  639  ANDAMAN AND NICOBAR ISLANDS
# 639                  640  ANDAMAN AND NICOBAR ISLANDS
#
#            _VijayDistrict_name  _VijayPopulation  _VijayMale  _VijayFemale  \
# 0                      Kupwara            870354      474190        396164
# 1                       Badgam            753745      398041        355704
# 2                  Leh(Ladakh)            133487       78971         54516
# ...
