# %% [markdown]
# ## Import the relevant python libraries for the analysis

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
file=r"C:\Users\vijay\OneDrive\Desktop\EDA Datasets csv\titanic.csv"
titanic=pd.read_csv(file)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.size
# Out:
# 10692

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# - ✅ 1. How many passengers were on board?

# %%
total_number_passangers=titanic.shape[0]
print('The total number of passangers is :',total_number_passangers)
# Out:
# The total number of passangers is : 891

# %% [markdown]
# - ✅ 2. What is the overall survival rate?

# %%
survied=titanic['Survived'].value_counts(normalize=True)*100
survied[1]
# Out:
# 38.38383838383838

# %% [markdown]
# - Another method

# %%
titanic['Survived'].mean()*100
# Out:
# 38.38383838383838

# %% [markdown]
# - What was the distribution of passengers by class (1st, 2nd, 3rd)?

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
class_names=titanic['Pclass'].value_counts().keys()
class_freq=titanic['Pclass'].value_counts().values

plt.bar(class_names,class_freq,color=['Red','Orange','Green'])
plt.xlabel('P class')
plt.ylabel('Counts')
plt.xticks([1,2,3])
plt.show()

# %%
# 🔹 Exploratory Data Analysis (EDA) Questions:
# How many passengers were on board the Titanic?

# What is the overall survival rate?

# What was the distribution of passengers by class (1st, 2nd, 3rd)?

# How does age affect survival?

# How many passengers were children (age < 12)?

# What was the gender distribution? Did gender affect survival rates?

# What is the average fare paid by passengers in each class?

# How many people embarked from each port (C = Cherbourg, Q = Queenstown, S = Southampton)?

# Is there any relationship between family size (SibSp + Parch) and survival?

# 🔹 Data Cleaning & Feature Engineering Questions:

# Are there any missing values? How will you handle them?

# Can you extract titles (Mr, Mrs, Miss, etc.) from the Name column and use them as a feature?

# Can you categorize ages into groups (Child, Teen, Adult, Senior)?

# Can you create a new feature "FamilySize" = SibSp + Parch + 1?

# Can you create a feature to indicate whether a passenger was alone or not?

# 🔹 Visualization Questions (Use Seaborn/Matplotlib):
# Plot the survival rate by gender.

# Plot the age distribution of survivors vs non-survivors.

# Plot a heatmap of correlations between numeric features.

# Plot survival rate by passenger class using a bar chart.

# Create a violin plot or box plot to compare fare distributions by class.

# 🔹 Machine Learning Questions:
# Can you build a model to predict survival? Try Logistic Regression first.

# Which features are most important for survival prediction?

# Can you improve accuracy using Decision Trees, Random Forest, or XGBoost?

# How does the model performance change with and without feature engineering?

# Try using GridSearchCV or RandomizedSearchCV to tune model hyperparameters.

# Can you build a pipeline using sklearn.pipeline?

# 🔹 Advanced (Optional):
# Try using ensemble methods like VotingClassifier or StackingClassifier.

# Perform cross-validation and report average accuracy.

# Use SHAP values or feature importance to explain your model.

# Can you handle imbalanced data if survival rates are skewed?

# Can you submit your results to Kaggle and beat the baseline score?

# %% [markdown]
# - How many passengers were children (age < 12)?

# %%
titanic.head(2)

# %%
children=titanic[titanic['Age']<12]
children

# %%
len(children)

# %% [markdown]
# - What was the gender distribution? Did gender affect survival rates?

# %%
titanic.head(2)

# %%
keys=titanic['Sex'].value_counts().keys()
values=titanic['Sex'].value_counts().values
plt.bar(keys,values,color=['Red','Green'])
plt.title('Distribution of the gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
titanic['Sex'].value_counts()

# %%
titanic.head(2)

# %%
titanic.groupby('Sex')['Survived'].mean()

# %% [markdown]
# - What is the average fare paid by passengers in each class?

# %%
titanic.head(2)

# %%
titanic.groupby('Pclass')['Fare'].mean()

# %% [markdown]
# - How many people embarked from each port (C = Cherbourg, Q = Queenstown, S = Southampton)?

# %%
titanic.head(2)

# %%
titanic['Embarked'].value_counts()

# %% [markdown]
# - Is there any relationship between family size (SibSp + Parch) and survival?

# %%
titanic['Family_size']=titanic['SibSp']+titanic['Parch']

# %%
titanic.head(2)

# %%
titanic['Family_size'].value_counts()

# %%
titanic.groupby('Family_size')['Survived'].mean()

# %% [markdown]
# - Are there any missing values? How will you handle them?

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
mean_age=round(titanic['Age'].mean(),2)
titanic.fillna(mean_age,inplace=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
file=r"C:\Users\vijay\OneDrive\Desktop\EDA Datasets csv\titanic.csv"
titanic=pd.read_csv(file)

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')
titanic['Age'].fillna(titanic['Age'].mean(),inplace=True)

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# - Can you extract titles (Mr, Mrs, Miss, etc.) from the Name column and use them as a feature?

# %%
titanic['Title']=titanic['Name'].str.extract(r'(Mr|Mrs|Miss|Dr)\.')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# - Can you categorize ages into groups (Child, Teen, Adult, Senior)?

# %%
def age_group(Age):
    if Age<=12:
        return 'Child'
    elif Age<=19:
        return 'Teen'
    elif Age<=59:
        return 'Adult'
    else:
        return 'Senior'
titanic['Age_group']=titanic['Age'].apply(age_group)

titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title Age_group
# 0      0         A/5 21171   7.2500   NaN        S    Mr     Adult
# 1      0          PC 17599  71.2833   C85        C   Mrs     Adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss     Adult
# ...

# %%
titanic['Age_group'].value_counts()
# Out:
# Age_group
# Adult     701
# Teen       95
# Child      69
# Senior     26
# Name: count, dtype: int64

# %% [markdown]
# - Can you create a new feature "FamilySize" = SibSp + Parch + 1?

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Title Age_group
# 0      0  A/5 21171   7.2500   NaN        S    Mr     Adult
# 1      0   PC 17599  71.2833   C85        C   Mrs     Adult

# %%
titanic['FamilySize']=titanic['SibSp']+titanic['Parch']+1

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# - Can you create a feature to indicate whether a passenger was alone or not?

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Title Age_group  FamilySize
# 0      0  A/5 21171   7.2500   NaN        S    Mr     Adult           2
# 1      0   PC 17599  71.2833   C85        C   Mrs     Adult           2

# %%
titanic['Isalone']=0
titanic.loc[titanic['FamilySize']==1,'Isalone']=1
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Title Age_group  FamilySize  \
# 0      0  A/5 21171   7.2500   NaN        S    Mr     Adult           2
# 1      0   PC 17599  71.2833   C85        C   Mrs     Adult           2
#
#    Isalone
# 0        0
# 1        0

# %%
titanic['Isalone'].value_counts()
# Out:
# Isalone
# 1    537
# 0    354
# Name: count, dtype: int64

# %% [markdown]
# ## 🔹 Visualization Questions (Use Seaborn/Matplotlib):

# %% [markdown]
# - Plot the survival rate by gender.

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Title Age_group  FamilySize  \
# 0      0  A/5 21171   7.2500   NaN        S    Mr     Adult           2
# 1      0   PC 17599  71.2833   C85        C   Mrs     Adult           2
#
#    Isalone
# 0        0
# 1        0

# %%
bar_plot=titanic.groupby('Sex')['Survived'].mean()
keys=bar_plot.keys()
values=bar_plot.values
plt.figure(figsize=(10,5))
plt.bar(keys,values,color=['Orange','Green'])
plt.title('How many members survival rate by gender')
plt.xticks()
plt.show()

# %%
bar_plot
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
# Total number of survivors by gender
survivors_by_gender = titanic[titanic['Survived'] == 1]['Sex'].value_counts()

# Plot
plt.figure(figsize=(6,6))
plt.pie(survivors_by_gender, labels=survivors_by_gender.index, autopct='%1.1f%%', colors=['lightblue', 'pink'])
plt.title('Survivors by Gender')
plt.show()

# %% [markdown]
# -  Plot the age distribution of survivors vs non-survivors.

# %%
surviver=titanic[titanic['Survived']==1]['Sex'].value_counts()
non_surviver=titanic[titanic['Survived']==0]['Sex'].value_counts()
df=pd.DataFrame({'Surviver':surviver,'Non-Surviver':non_surviver})
df.plot(kind='bar',figsize=(10,5),color=['Green','Orange'])
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# - Plot a heatmap of correlations between numeric features.

# %%
correlation=titanic.corr(numeric_only=True)
correlation
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# Age             0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SibSp          -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.179191  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.091566  0.159651  0.216225
# FamilySize     -0.040143  0.016639  0.065997 -0.248512  0.890712  0.783111
# Isalone         0.057462 -0.203367  0.135207  0.179775 -0.584471 -0.583398
#
#                  Fare  FamilySize   Isalone
# PassengerId  0.012658   -0.040143  0.057462
# Survived     0.257307    0.016639 -0.203367
# Pclass      -0.549500    0.065997  0.135207
# ...

# %%
sns.heatmap(correlation,annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap of Titanic Numeric Features")
plt.show()

# %% [markdown]
# - Plot survival rate by passenger class using a bar chart.

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Title Age_group  FamilySize  \
# 0      0  A/5 21171   7.2500   NaN        S    Mr     Adult           2
# 1      0   PC 17599  71.2833   C85        C   Mrs     Adult           2
#
#    Isalone
# 0        0
# 1        0

# %%
survival_rate=titanic.groupby('Survived')['Pclass'].mean()
keys=survival_rate.keys()
values=survival_rate.values
plt.bar(keys,values,color=['Orange','Lightblue','Green'])
plt.title(' survival rate by passenger')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.ylim(0,3)
plt.show()

# %% [markdown]
# -  Create a violin plot or box plot to compare fare distributions by class

# %%
plt.figure(figsize=(8,5))
x=titanic['Pclass']
y=titanic['Fare']

sns.boxplot(data=titanic, x=x, y=y, palette='Set2')

plt.title('Fare Distribution by Passenger Class (Box Plot)')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.show()
